# %% [markdown]
# # API WEB SCRABING

# %% [markdown]
#  THE PROCESS OF THE WEB SCRABING
#  1. GOOGLE SEARCH FOR THE GOOGLE DEVLOPER CONSOLE
#  2. MAKE AN ACOUNT ON THAT WEBSITE
#  3. GO FOR THE CREDULANCE MENU FOR THE API DEVOLOP
#  4. MAKE AND COPY THAT API FOR YOUTUBE OR OTHER WEBSITE
#
#  5. AFTER MAKING THE API FOR MAKE A NEW PROJECT NAME
#  6. THEN FOR THE CHANNELS THEN LIST THE ....................
#  7. COPY THAT CHANNEL KEY FROM THE YOUTUBE
#  8. WRITE CODE IMPORT GOOGLEAPICLIENT. DISCOVERY IMPORT BUILT
#  IMPORT SEABORN  AS SNS
#  IMPORT PANDAS AS PD
#  9. API_KEYS=""
#  CHANNEL_ID=""
#  YOUTUBE=BUILT(SERIVEC=YOUTUBE,VERSION=V3,API="")
#  10. MAKE A FUNCTION TO COLECTING THE DATA FROM THE YOUTUBE
#  DEF NAME(YOUTUBE,CHANNEL_ID):
#  ....TO MAKE REQUEST FOR COLLECT THE DATA FROM THE YOUTUBE
#      REQUEST=REQUEST=YOUTUBE.CHANNEL().LIST(PART="SNIPPERT,CONTENT DETAIL ,STATICS"
#      ID=CHANNEL_ID
#     RESPANCE= REQUEST.EXECUTE()
#     RETURN RESPANCE

# %%
pip install google-api-python-client
# YOUTUBE API DACUMENT  WEBSITE
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build





import pandas as pd 
import seaborn as sns
import numpy as np

# %%
api_keys="YOUR API KEY"
channel_id=["UCBwmMxybNva6P_5VmxjzwqA",'UCjvgGbPPn-FgYeguc5nxG4A','UCx1VY57UmjU76Tgq8YwkklA','UCvfH3RaugUbIqY-80iOED4Q','UC-NsJvzVX7Z72cbVh-hWngQ']
youtube=build("youtube","v3",developerKey=api_keys)

# %%
def collect_data_y(youtube,channel_id):
    data=[]
    for i in channel_id:
        request=youtube.channels().list(
                part="snippet,contentDetails,statistics",
                id=i)
        responce=request.execute()
        print(responce)
        dic=dict(title=responce["items"][0]["snippet"]["title"],
                 views=responce["items"][0]["statistics"]["viewCount"],
                 subs=responce["items"][0]["statistics"]["subscriberCount"],
                 videos=responce["items"][0]["statistics"]["videoCount"])

        data.append(dic)
    
    print(data)      
    global df    
    df=pd.DataFrame(data)
#     print(data)
    return df
collect_data_y(youtube,channel_id)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'dey-l6pmvFAIUy-o9mMIY2X1Mxs', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'gE6tkpD2uDamOdEh4n19VGgfb04', 'id': 'UCBwmMxybNva6P_5VmxjzwqA', 'snippet': {'title': 'Apna College', 'description': "I'm Shradha, Ex-Microsoft Software Engineer, DRDO. My journey started from a small village of Haryana, in college I learned coding and got 2 internships at Microsoft, work for DRDO, invited for Google SPS and a Full Time Offer from Microsoft. I believe that skills are more important today and want to help students to learn & crack their dream companies ❤️\nSo, I left my Microsoft Job and started to teach students. I love my students and I love sharing my learnings.\nTo Chalo Phodte hain!\n\n\nFeel free to contact Shradha Didi for Seminars, Hackathons & Collaborations at the given email id below.\n\n\n", 'customUrl': '@apnacollegeofficial', 'publishedAt': '2020-08-05T16:09:28.304314Z', 'thumbn
# ...

# %%
df=collect_data_y(youtube,channel_id)
# Out:
#                 title        views      subs videos
# 0        Apna College    717336727   4670000    792
# 1  Sourav Joshi Vlogs  10938189686  23900000   1548
# 2     Unacademy India    410366664   1420000     73
# 3   ADGPI-INDIAN ARMY     55035940    668000    648

# %%
for i in ["views","subs","videos"]:


    df[i]=df[i].astype("int64")

# %%
# # letus visulize it

# %%
import matplotlib.pyplot as plt

# %%
bar=sns.barplot(x="subs",y="title",data=df,color="red")
# plt.show()

# %%
bar=sns.barplot(x="views",y="title",data=df,color="red")

# %%
bar=sns.barplot(x="videos",y="title",data=df,color="red")

# %%
channel_v_id='UU-NsJvzVX7Z72cbVh-hWngQ'
youtube=build("youtube","v3",developerKey="AIzaSyBB99Ttcwd8XIJye7WXkKPqr4zigt8g768")

# %%
def shreyance_channel(youtube,channel_v_id):
    request=youtube.playlistItems().list(
        part="contentDetails",
        playlistId=channel_v_id
    
    
    )
#     print(request)
    response=request.execute()
    return response
shreyance_channel(youtube,channel_v_id)
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'M3F1EmFC-BLsXXEOHtKe25cNd8M',
#  'nextPageToken': 'EAAafVBUOkNBVWlFREV5UlVaQ00wSXhRelUzUkVVMFJURW9BVWpqN3VMUWhLNkRBMUFCV2pnaVEyaG9WbFpUTVU5ak1IQXlaV3hhV1U0eGJ6Tk5iVTVwVm0xbmRHRkdaSFZhTVVWVFJFRnBMV2xMTW5OQ2FFTTBNMW95Y2tGM0ln',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'c8qcDJu9ZxQinwjDPvoGXVL-rK8',
#    'id': 'VVUtTnNKdnpWWDdaNzJjYlZoLWhXbmdRLkV4bWdPSlBmQ0dz',
#    'contentDetails': {'videoId': 'ExmgOJPfCGs',
#     'videoPublishedAt': '2023-12-26T05:48:21Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'wI-BH__B_8DmnDq75928Ohe-Ii4',
#    'id': 'VVUtTnNKdnpWWDdaNzJjYlZoLWhXbmdRLlozb19vUVhaTHIw',
#    'contentDetails': {'videoId': 'Z3o_oQXZLr0',
#     'videoPublishedAt': '2023-12-20T20:51:02Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'pIYSil5Mnea44WRJvJAtt3SRbxg',
#    'id': 'VVUtTnNKdnpWWDdaNzJjYlZoLWhXbmdRLk9iMGJjSXBvZWt3',
#    'contentDetails': {'videoId': 'Ob0bcIpoekw',
# ...

# %%
next_page='EAAafVBUOkNESWlFRGhETlVaQlJUWkNNVFkwT0RFelF6Z29BVWp0cU9UOG82LURBMUFCV2pnaVEyaG9WbFpZV20xVFJFNVRXVmhXYmxaWFNrcGpWbXQwVDBSQ2NGUXdWa1ZPUmtWVFJFRnFWVEZ4TFhOQ2FFUkpaMTgzVGtGUkln'

# %%
channel_v_id="UUvfH3RaugUbIqY-80iOED4Q"

def shreyance_channel(youtube,channel_v_id):
#     for i in 
    request=youtube.playlistItems().list(
        part="contentDetails",
        playlistId=channel_v_id,
        maxResults=50
    
    
    )
#     print(request)
    videos_ids=[]
    global response
    response=request.execute()
#     print(response)
    for i in range(len(response["items"])):
        videos_ids.append(response["items"][i]["contentDetails"]["videoId"])
        
        
    nextpagetoken=response.get("nexPageToken")
    more_page=True
    while more_page:
        if nextpagetoken is None:
            more_page=False
        else:
            request=youtube.playlistItems().list(
            playlistId=channel_v_id,
                maxResults=50,
                pageToken=nextpagetoken
            
            
            
            )
            for i in range(len(response["items"])):
                videos_ids.append(response["items"][i]["contentDetails"]["videoId"])
        
            nextpagetoken=response.get("nexPageToken")

    return videos_ids
videos_ids=shreyance_channel(youtube,channel_v_id)
response=response

# %%
def get_videos_details(youtube,videos_ids):
    for i in range(0,len(videos_ids),50):
        request=youtube.videos().list(
        part="snippet,statistics",
        id=",".join(videos_ids[i:i+50]))

    response=request.execute()
        
        
    all_video_stats=[]
    for video in response["items"]:
        video_stats=dict(title=video["snippet"]["title"],
                        published_date=video["snippet"]["publishedAt"],
                        views=video["statistics"]["viewCount"],
                         
#                         dislike=video["statistics"]["dislikeCount"],
                        like=video["statistics"]["likeCount"],
                        comments=video["statistics"]["commentCount"])
                        
                        
                       
        all_video_stats.append(video_stats)
    df=pd.DataFrame(all_video_stats)
    
    return df
df=get_videos_details(youtube,videos_ids)

# %%
df
# Out:
#                                                 title published_date   views  \
# 0                            Train Hard, Train Tough.     2023-12-26    4805
# 1   Prepared for Today, Tomorrow and Forever. #ind...     2023-12-19   14991
# 2                     16 December...Vijay Diwas...!!!     2023-12-16   10358
# 3          तवारीख़ में दर्ज़ एक तारीख़....16 दिसम्बर।     2023-12-14    3945
# 4            Join Indian Army. Do you have it in you?     2023-12-08   12917
# 5   Fearless soldiers of Indian Army. #indianarmy ...     2023-12-08   25241
# 6   Indian Army Quiz 2023 – Battle of Minds | Indi...     2023-12-03   10846
# 7      Indian Army Officers retiring in November 2023     2023-11-30   19733
# 8   Captain Jintu Gogoi, Vir Chakra(P) Memorial Fo...     2023-11-20    3302
# 9   📽️ LIVE | IndianArmy Quiz 2023 |  Battle of Mi...     2023-11-20    6979
# 10  Sikkim Floods: Humanitarian Assistance by #Ind...     2023-11-08    5791
# ...

# %%
df["published_date"]=pd.to_datetime(df["published_date"]).dt.date

df["views"]=pd.to_numeric(df["views"])
df["like"]=pd.to_numeric(df["like"])

df["comments"]=pd.to_numeric(df["comments"])

df
# Out:
#                                                 title published_date   views  \
# 0                            Train Hard, Train Tough.     2023-12-26    4805
# 1   Prepared for Today, Tomorrow and Forever. #ind...     2023-12-19   14991
# 2                     16 December...Vijay Diwas...!!!     2023-12-16   10358
# 3          तवारीख़ में दर्ज़ एक तारीख़....16 दिसम्बर।     2023-12-14    3945
# 4            Join Indian Army. Do you have it in you?     2023-12-08   12917
# 5   Fearless soldiers of Indian Army. #indianarmy ...     2023-12-08   25241
# 6   Indian Army Quiz 2023 – Battle of Minds | Indi...     2023-12-03   10846
# 7      Indian Army Officers retiring in November 2023     2023-11-30   19733
# 8   Captain Jintu Gogoi, Vir Chakra(P) Memorial Fo...     2023-11-20    3302
# 9   📽️ LIVE | IndianArmy Quiz 2023 |  Battle of Mi...     2023-11-20    6979
# 10  Sikkim Floods: Humanitarian Assistance by #Ind...     2023-11-08    5791
# ...

# %%
df.dtypes
# Out:
# title             object
# published_date    object
# views              int64
# like               int64
# comments           int64
# dtype: object

# %%
pip install --upgrade seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
new=df.sort_values(by="views",ascending=False).head(10)
new
# Out:
#                                                 title published_date   views  \
# 34                            Indian Military Academy     2023-06-07  830889
# 38  "Forging Steel…. The Drill Ustads." #MondayMot...     2023-05-22  669372
# 37                    NDA SONG ‘BharatMaaTujheSalaam’     2023-05-30  322805
# 41                        The New "Thal Sena Bhawan".     2023-04-26  232003
# 28                            Independence Day 2023🇮🇳     2023-08-15   77779
# 42  #IndianArmy Para Commandos in Action. #OnPathT...     2023-04-24   69090
# 17  Joint Training during Exercise Yudh Abhyas in ...     2023-10-03   30619
# 23  Jumps from aircraft during Exercise Bright Sta...     2023-09-14   29497
# 15  Relive the adrenaline rush.. in the Joint Exer...     2023-10-04   28159
# 5   Fearless soldiers of Indian Army. #indianarmy ...     2023-12-08   25241
#
#      like  comments
# 34  28726       325
# 38  11902       216
# 37  19964       843
# 41   5673       267
# ...

# %%
import matplotlib.pyplot as plt
plt.bar(x=new["title"],height=new["views"] )
plt.show()

# %%
import seaborn as sns

sns.barplot(data=new,x="views",y="title")
# Out:
# <Axes: xlabel='views', ylabel='title'>
# C:\Users\vksuj\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 127470 (\N{REGIONAL INDICATOR SYMBOL LETTER I}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\vksuj\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 127475 (\N{REGIONAL INDICATOR SYMBOL LETTER N}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\vksuj\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 127466 (\N{REGIONAL INDICATOR SYMBOL LETTER E}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\vksuj\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 127468 (\N{REGIONAL INDICATOR SYMBOL LETTER G}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\vksuj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 127470 (\N{REGIONAL INDICATOR SYMBOL LETTER I}) missing from current font.
# ...
